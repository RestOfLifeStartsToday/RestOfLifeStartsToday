# %% [markdown]
# # Project Statement

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Initialization" data-toc-modified-id="Initialization-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Initialization</a></span></li><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load Data</a></span><ul class="toc-item"><li><span><a href="#Data-description" data-toc-modified-id="Data-description-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data description</a></span></li><li><span><a href="#Missing-values-check" data-toc-modified-id="Missing-values-check-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Missing values check</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span></li><li><span><a href="#Evaluation-Procedure" data-toc-modified-id="Evaluation-Procedure-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Evaluation Procedure</a></span></li><li><span><a href="#Normalization" data-toc-modified-id="Normalization-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Normalization</a></span></li><li><span><a href="#Train-/-Test-Split" data-toc-modified-id="Train-/-Test-Split-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Train / Test Split</a></span></li><li><span><a href="#Working-with-models" data-toc-modified-id="Working-with-models-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Working with models</a></span><ul class="toc-item"><li><span><a href="#Language-preprocessing" data-toc-modified-id="Language-preprocessing-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Language preprocessing</a></span><ul class="toc-item"><li><span><a href="#NLTK,-TF-IDF" data-toc-modified-id="NLTK,-TF-IDF-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>NLTK, TF-IDF</a></span></li><li><span><a href="#spaCy,-TF-IDF" data-toc-modified-id="spaCy,-TF-IDF-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>spaCy, TF-IDF</a></span></li><li><span><a href="#BERT" data-toc-modified-id="BERT-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>BERT</a></span></li></ul></li><li><span><a href="#Dummy-model---Constant" data-toc-modified-id="Dummy-model---Constant-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Dummy model - Constant</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#NLTK,-TF-IDF" data-toc-modified-id="NLTK,-TF-IDF-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>NLTK, TF-IDF</a></span></li><li><span><a href="#spaCy,-TF-IDF" data-toc-modified-id="spaCy,-TF-IDF-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>spaCy, TF-IDF</a></span></li><li><span><a href="#BERT" data-toc-modified-id="BERT-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>BERT</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-7.3.4"><span class="toc-item-num">7.3.4&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#LGBMClassifier" data-toc-modified-id="LGBMClassifier-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>LGBMClassifier</a></span><ul class="toc-item"><li><span><a href="#NLTK,-TF-IDF" data-toc-modified-id="NLTK,-TF-IDF-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>NLTK, TF-IDF</a></span></li><li><span><a href="#spaCy,-TF-IDF" data-toc-modified-id="spaCy,-TF-IDF-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>spaCy, TF-IDF</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-7.4.3"><span class="toc-item-num">7.4.3&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#RandomForestClassifier" data-toc-modified-id="RandomForestClassifier-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>RandomForestClassifier</a></span><ul class="toc-item"><li><span><a href="#NLTK,-TF-IDF" data-toc-modified-id="NLTK,-TF-IDF-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>NLTK, TF-IDF</a></span></li><li><span><a href="#spaCy,-TF-IDF" data-toc-modified-id="spaCy,-TF-IDF-7.5.2"><span class="toc-item-num">7.5.2&nbsp;&nbsp;</span>spaCy, TF-IDF</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-7.5.3"><span class="toc-item-num">7.5.3&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li></ul></li><li><span><a href="#My-Reviews" data-toc-modified-id="My-Reviews-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>My Reviews</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression---NLTK" data-toc-modified-id="Logistic-Regression---NLTK-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Logistic Regression - NLTK</a></span></li><li><span><a href="#Logistic-Regression---spaCy" data-toc-modified-id="Logistic-Regression---spaCy-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Logistic Regression - spaCy</a></span></li><li><span><a href="#BERT" data-toc-modified-id="BERT-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>BERT</a></span><ul class="toc-item"><li><span><a href="#Conclusion---My-Reviews" data-toc-modified-id="Conclusion---My-Reviews-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Conclusion - My Reviews</a></span></li></ul></li></ul></li><li><span><a href="#Conclusions" data-toc-modified-id="Conclusions-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Conclusions</a></span></li></ul></div>

# %% [markdown]
# The Film Junky Union, a new edgy community for classic movie enthusiasts, is developing a system for filtering and categorizing movie reviews. The goal is to train a model to automatically detect negative reviews. You'll be using a dataset of IMBD movie reviews with polarity labelling to build a model for classifying positive and negative reviews. It will need to have an F1 score of at least 0.85.

# %% [markdown]
# ## Initialization

# %%
import math

import numpy as np
import pandas as pd
import re

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

from sklearn.pipeline import make_pipeline
from tqdm.auto import tqdm

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
# the next line provides graphs of better quality on HiDPI screens
# %config InlineBackend.figure_format = 'retina'

plt.style.use('seaborn')

# %%
# this is to use progress_apply, read more at https://pypi.org/project/tqdm/#pandas-integration
tqdm.pandas()
# Out:
# C:\Users\eliram\anaconda3\lib\site-packages\tqdm\std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# ## Load Data

# %%
df_reviews = pd.read_csv('datasets/imdb_reviews.tsv', sep='\t', dtype={'votes': 'Int64'})

# %%
df_reviews.head(2)
# Out:
#       tconst title_type primary_title original_title  start_year end_year  \
# 0  tt0068152      movie             $              $        1971       \N
# 1  tt0068152      movie             $              $        1971       \N
#
#   runtime_minutes  is_adult              genres  average_rating  votes  \
# 0             121         0  Comedy,Crime,Drama             6.3   2218
# 1             121         0  Comedy,Crime,Drama             6.3   2218
#
#                                               review  rating   sp  pos  \
# 0  The pakage implies that Warren Beatty and Gold...       1  neg    0
# 1  How the hell did they get this made?! Presenti...       1  neg    0
#
#   ds_part   idx
# 0   train  8335
# 1   train  8336

# %% [markdown]
# ### Data description

# %% [markdown]
# There are 2 main fields:
# `revie`: the review text
# `pos`: the target, '0' for negative and '1' for positive
# `ds_part`: : 'train'/'test' for the train/test part of dataset, correspondingly

# %% [markdown]
# Other fields in use in the project:

# %% [markdown]
# `start_year`: The year the title was released
# `tconst`: Title ID
# `runtime_minutes`: The length of the title
# `original_title`: The original name of the title
# `primary_title`: The primary name the title was published with
# `is_adult`: If it's an adult title
# `title_type`: The type of the title, like: movie, tvMovie, video, tvSeries, etc.
# `genres`: The genere of the title like: Comedy, Crime, Drama, Mystery, Animation, Biography, etc.
# `average_rating`: Average rating for the title
# `votes`: Number of votes made for the title
# `review`: A review for the title
# `rating`: The rating got from that reviewer
# `sp`: Like the target - neg for negative, pos for positive
# `idx`: The ID of the review

# %% [markdown]
# ### Missing values check

# %%
df_reviews.isna().sum()
# Out:
# tconst             0
# title_type         0
# primary_title      0
# original_title     0
# start_year         0
# end_year           0
# runtime_minutes    0
# is_adult           0
# genres             0
# average_rating     2
# votes              2
# review             0
# rating             0
# sp                 0
# pos                0
# ds_part            0
# idx                0
# dtype: int64

# %% [markdown]
# There missing values in 2 unimportant fields for our check, and only in 2 lines out of 47331 rows.
# I'm dropping those rows.

# %%
df_reviews=df_reviews.dropna()

# %% [markdown]
# ## EDA

# %% [markdown]
# Let's check the number of movies and reviews over years.

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 8))

ax = axs[0]

dft1 = df_reviews[['tconst', 'start_year']].drop_duplicates() \
    ['start_year'].value_counts().sort_index()
dft1 = dft1.reindex(index=np.arange(dft1.index.min(), max(dft1.index.max(), 2021))).fillna(0)
dft1.plot(kind='bar', ax=ax)
ax.set_title('Number of Movies Over Years')

ax = axs[1]

dft2 = df_reviews.groupby(['start_year', 'pos'])['pos'].count().unstack()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2021))).fillna(0)

dft2.plot(kind='bar', stacked=True, label='#reviews (neg, pos)', ax=ax)

dft2 = df_reviews['start_year'].value_counts().sort_index()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2021))).fillna(0)
dft3 = (dft2/dft1).fillna(0)
axt = ax.twinx()
dft3.reset_index(drop=True).rolling(5).mean().plot(color='orange', label='reviews per movie (avg over 5 years)', ax=axt)

lines, labels = axt.get_legend_handles_labels()
ax.legend(lines, labels, loc='upper left')

ax.set_title('Number of Reviews Over Years')

fig.tight_layout()

# %% [markdown]
# Let's check the distribution of number of reviews per movie with the exact counting and KDE (just to learn how it may differ from the exact counting)

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 5))

ax = axs[0]
dft = df_reviews.groupby('tconst')['review'].count() \
    .value_counts() \
    .sort_index()
dft.plot.bar(ax=ax)
ax.set_title('Bar Plot of #Reviews Per Movie')

ax = axs[1]
dft = df_reviews.groupby('tconst')['review'].count()
sns.kdeplot(dft, ax=ax)
ax.set_title('KDE Plot of #Reviews Per Movie')

fig.tight_layout()

# %% [markdown]
# Checking if the target feature is balanced

# %%
df_reviews['pos'].value_counts()
# Out:
# 0    23715
# 1    23616
# Name: pos, dtype: int64

# %%
balance=df_reviews['pos'].value_counts()
'Negative:Positive ratio: {:.2%}:{:.2%}'.format(balance[0]/len(df_reviews),balance[1]/len(df_reviews))
# Out:
# 'Negative:Positive ratio: 50.11%:49.89%'

# %% [markdown]
# The dataset is balanced.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

ax = axs[0]
dft = df_reviews.query('ds_part == "train"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('The train set: distribution of ratings')

ax = axs[1]
dft = df_reviews.query('ds_part == "test"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('The test set: distribution of ratings')

fig.tight_layout()

# %% [markdown]
# __Conclusion__
# Looking at the distribution of ratings given to the titles in the dataset indicates that the rating is very balanced between the training and test datasets.
# The training and test datasets are very balanced if it is in the perspective of the number of negative/positive reviews, or even the distribution of ratings that each title received.

# %% [markdown]
# Distribution of negative and positive reviews over the years for two parts of the dataset

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 8), gridspec_kw=dict(width_ratios=(2, 1), height_ratios=(1, 1)))

ax = axs[0][0]

dft = df_reviews.query('ds_part == "train"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('The train set: number of reviews of different polarities per year')

ax = axs[0][1]

dft = df_reviews.query('ds_part == "train"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('The train set: distribution of different polarities per movie')

ax = axs[1][0]

dft = df_reviews.query('ds_part == "test"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('The test set: number of reviews of different polarities per year')

ax = axs[1][1]

dft = df_reviews.query('ds_part == "test"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('The test set: distribution of different polarities per movie')

fig.tight_layout()
# Out:
# C:\Users\eliram\anaconda3\lib\site-packages\seaborn\distributions.py:1668: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# C:\Users\eliram\anaconda3\lib\site-packages\seaborn\distributions.py:1668: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# C:\Users\eliram\anaconda3\lib\site-packages\seaborn\distributions.py:1668: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# C:\Users\eliram\anaconda3\lib\site-packages\seaborn\distributions.py:1668: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# __Conclusion__
# The distribution of negative and positive reviews over the years for two parts of the dataset is very similar, but although the graphs are not identical, it's very balanced, although the balance or imbalance of the distribution over the years is not supposed to interfere in the model training task, as long as the dataset is balanced.

# %% [markdown]
# ## Evaluation Procedure

# %% [markdown]
# Composing an evaluation routine which can be used for all models in this project

# %%
import sklearn.metrics as metrics

def evaluate_model(model, train_features, train_target, test_features, test_target):
    
    eval_stats = {}
    
    fig, axs = plt.subplots(1, 3, figsize=(20, 6)) 
    
    for type, features, target in (('train', train_features, train_target), ('test', test_features, test_target)):
        
        eval_stats[type] = {}
    
        pred_target = model.predict(features)
        pred_proba = model.predict_proba(features)[:, 1]
        
        # F1
        f1_thresholds = np.arange(0, 1.01, 0.05)
        f1_scores = [metrics.f1_score(target, pred_proba>=threshold) for threshold in f1_thresholds]
        
        # ROC
        fpr, tpr, roc_thresholds = metrics.roc_curve(target, pred_proba)
        roc_auc = metrics.roc_auc_score(target, pred_proba)    
        eval_stats[type]['ROC AUC'] = roc_auc

        # PRC
        precision, recall, pr_thresholds = metrics.precision_recall_curve(target, pred_proba)
        aps = metrics.average_precision_score(target, pred_proba)
        eval_stats[type]['APS'] = aps
        
        if type == 'train':
            color = 'blue'
        else:
            color = 'green'

        # F1 Score
        ax = axs[0]
        max_f1_score_idx = np.argmax(f1_scores)
        ax.plot(f1_thresholds, f1_scores, color=color, label=f'{type}, max={f1_scores[max_f1_score_idx]:.2f} @ {f1_thresholds[max_f1_score_idx]:.2f}')
        # setting crosses for some thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(f1_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(f1_thresholds[closest_value_idx], f1_scores[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('threshold')
        ax.set_ylabel('F1')
        ax.legend(loc='lower center')
        ax.set_title(f'F1 Score') 

        # ROC
        ax = axs[1]    
        ax.plot(fpr, tpr, color=color, label=f'{type}, ROC AUC={roc_auc:.2f}')
        # setting crosses for some thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(roc_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'            
            ax.plot(fpr[closest_value_idx], tpr[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.plot([0, 1], [0, 1], color='grey', linestyle='--')
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('FPR')
        ax.set_ylabel('TPR')
        ax.legend(loc='lower center')        
        ax.set_title(f'ROC Curve')
        
        # PRC
        ax = axs[2]
        ax.plot(recall, precision, color=color, label=f'{type}, AP={aps:.2f}')
        # setting crosses for some thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(pr_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(recall[closest_value_idx], precision[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('recall')
        ax.set_ylabel('precision')
        ax.legend(loc='lower center')
        ax.set_title(f'PRC')        

        eval_stats[type]['Accuracy'] = metrics.accuracy_score(target, pred_target)
        eval_stats[type]['F1'] = metrics.f1_score(target, pred_target)
    
    df_eval_stats = pd.DataFrame(eval_stats)
    df_eval_stats = df_eval_stats.round(2)
    df_eval_stats = df_eval_stats.reindex(index=('Accuracy', 'F1', 'APS', 'ROC AUC'))
    
    print(df_eval_stats)
    
    return

# %% [markdown]
# ## Normalization

# %% [markdown]
# We assume all models below accepts texts in lowercase and without any digits, punctuations marks etc.

# %%
def clear_text(text):
    pattern = r"[^a-zA-Z']"
    cleaned_with_spaces = re.sub(pattern, " ", text)
    return (' '.join(cleaned_with_spaces.split())).lower()

# %%
df_reviews['review_norm'] = df_reviews.review.apply(lambda x: clear_text(x))
df_reviews.head(2)
# Out:
#       tconst title_type primary_title original_title  start_year end_year  \
# 0  tt0068152      movie             $              $        1971       \N
# 1  tt0068152      movie             $              $        1971       \N
#
#   runtime_minutes  is_adult              genres  average_rating  votes  \
# 0             121         0  Comedy,Crime,Drama             6.3   2218
# 1             121         0  Comedy,Crime,Drama             6.3   2218
#
#                                               review  rating   sp  pos  \
# 0  The pakage implies that Warren Beatty and Gold...       1  neg    0
# 1  How the hell did they get this made?! Presenti...       1  neg    0
#
#   ds_part   idx                                        review_norm
# 0   train  8335  the pakage implies that warren beatty and gold...
# 1   train  8336  how the hell did they get this made presenting...

# %% [markdown]
# ## Train / Test Split

# %% [markdown]
# Luckily, the whole dataset is already divided into train/test one parts. The corresponding flag is 'ds_part'.

# %%
df_reviews_train = df_reviews.query('ds_part == "train"').copy()
df_reviews_test = df_reviews.query('ds_part == "test"').copy()

train_target = df_reviews_train['pos']
test_target = df_reviews_test['pos']

print(df_reviews_train.shape)
print(df_reviews_test.shape)
# Out:
# (23796, 18)
# (23533, 18)

# %% [markdown]
# ## Working with models

# %% [markdown]
# ### Language preprocessing

# %% [markdown]
# #### NLTK, TF-IDF

# %%
import nltk

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer  = WordNetLemmatizer()

def lemmatize_nltk(text):
    tokens = word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]
    return " ".join(lemmas)

# %%
# %%time
df_reviews_train['lemmas_nltk'] = df_reviews_train.review_norm.apply(lemmatize_nltk)
df_reviews_test['lemmas_nltk'] = df_reviews_test.review_norm.apply(lemmatize_nltk)
# Out:
# Wall time: 1min 39s

# %%
stop_words = set(stopwords.words('english'))
count_tf_idf = TfidfVectorizer(stop_words=stop_words)

# %%
# %%time

# the features
tf_idf_nltk_train = count_tf_idf.fit_transform(df_reviews_train['lemmas_nltk'])
tf_idf_nltk_test = count_tf_idf.transform(df_reviews_test['lemmas_nltk'])
# Out:
# Wall time: 8.56 s

# %% [markdown]
# #### spaCy, TF-IDF

# %%
import spacy

nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
def lemmatize_spacy(text):
    doc = nlp(text)
    lemmas = [token.lemma_ for token in doc]
    return " ".join(lemmas)

# %%
# %%time
df_reviews_train['lemmas_spacy'] = df_reviews_train.review_norm.apply(lemmatize_spacy)
df_reviews_test['lemmas_spacy'] = df_reviews_test.review_norm.apply(lemmatize_spacy)
# Out:
# Wall time: 13min 47s

# %%
count_tf_idf_spacy = TfidfVectorizer(stop_words=stop_words)

# %%
tf_idf_spacy_train = count_tf_idf_spacy.fit_transform(df_reviews_train['lemmas_spacy'])
tf_idf_spacy_test = count_tf_idf_spacy.transform(df_reviews_test['lemmas_spacy'])

# %% [markdown]
# #### BERT

# %% [markdown]
# <div class="alert alert-info">
#     USED <strong>BERT</strong> TO PROCESS 2000 ROWS ON A COMPUTER WITHOUT CUDA SUPPORT.
# </div>

# %%
import torch
import transformers

# %%
tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-uncased')
config = transformers.BertConfig.from_pretrained('bert-base-uncased')
model = transformers.BertModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def BERT_text_to_embeddings(texts, max_length=512, batch_size=100, \
                            force_device=None, disable_progress_bar=False):
    
    ids_list = []
    attention_mask_list = []

    # text to padded ids of tokens along with their attention masks
    for input_text in texts:
        ids = tokenizer.encode(
            input_text.lower(),
            add_special_tokens=True,
            truncation=True,
            max_length=max_length,
        )
        padded = np.array(ids + [0] * (max_length - len(ids)))
        attention_mask = np.where(padded != 0, 1, 0)
        ids_list.append(padded)
        attention_mask_list.append(attention_mask)
    
    if force_device is not None:
        device = torch.device(force_device)
    else:
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
    model.to(device)
    if not disable_progress_bar:
        print(f'Using the {device} device.')
    
    # gettings embeddings in batches

    embeddings = []

    for i in tqdm(range(math.ceil(len(ids_list)/batch_size)), disable=disable_progress_bar):
            
        ids_batch = torch.LongTensor(
            ids_list[batch_size*i:batch_size*(i+1)]
        ).to(device)
        
        attention_mask_batch = torch.LongTensor(
            attention_mask_list[batch_size * i : batch_size * (i + 1)]
        )
            
        with torch.no_grad():            
            model.eval()
            batch_embeddings = model(input_ids=ids_batch, attention_mask=attention_mask_batch)   
        embeddings.append(batch_embeddings[0][:,0,:].detach().cpu().numpy())
        
    return np.concatenate(embeddings)

# %%
# %%time
# Attention! Running BERT for thousands of texts may take long run on CPU, at least several hours
train_features_bert = BERT_text_to_embeddings(df_reviews_train['review_norm'][:1000]) #, force_device='cuda')
test_features_bert = BERT_text_to_embeddings(df_reviews_test['review_norm'][:1000]) #, force_device='cuda')
# Out:
# Using the cpu device.
# ...
# Using the cpu device.
# ...
# Wall time: 1h 10min 43s

# %%
# Attention! Running BERT for thousands of texts may take long run on CPU, at least several hours
train_features_bert2K = BERT_text_to_embeddings(df_reviews_train['review_norm'][:2000]) #, force_device='cuda')
test_features_bert2K = BERT_text_to_embeddings(df_reviews_test['review_norm'][:2000]) #, force_device='cuda')
# Out:
# Using the cpu device.
# ...
# Using the cpu device.
# ...

# %% [markdown]
# ### Dummy model - Constant

# %%
from sklearn.dummy import DummyClassifier

# %%
model_dummy=DummyClassifier()
model_dummy.fit(tf_idf_nltk_train, train_target)
# Out:
# DummyClassifier()

# %%
evaluate_model(model_dummy, tf_idf_nltk_train, train_target, tf_idf_nltk_test, test_target)
# Out:
#           train  test
# Accuracy    0.5   0.5
# F1          0.0   0.0
# APS         0.5   0.5
# ROC AUC     0.5   0.5

# %% [markdown]
# Running a dummy model just as a baseline. There are no surprises, and the results are bad, and below the desired threshold.

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### NLTK, TF-IDF

# %%
model_lr_nltk = LogisticRegression(random_state=12345, solver='liblinear')
model_lr_nltk.fit(tf_idf_nltk_train, train_target)
# Out:
# LogisticRegression(random_state=12345, solver='liblinear')

# %%
evaluate_model(model_lr_nltk, tf_idf_nltk_train, train_target, tf_idf_nltk_test, test_target)
# Out:
#           train  test
# Accuracy   0.94  0.88
# F1         0.94  0.88
# APS        0.98  0.95
# ROC AUC    0.98  0.95

# %% [markdown]
# #### spaCy, TF-IDF

# %%
model_lr_spacy = LogisticRegression(random_state=12345, solver='liblinear')
model_lr_spacy.fit(tf_idf_spacy_train, train_target)
# Out:
# LogisticRegression(random_state=12345, solver='liblinear')

# %%
evaluate_model(model_lr_spacy, tf_idf_spacy_train, train_target, tf_idf_spacy_test, test_target)
# Out:
#           train  test
# Accuracy   0.93  0.88
# F1         0.93  0.88
# APS        0.98  0.95
# ROC AUC    0.98  0.95

# %% [markdown]
# #### BERT

# %% [markdown]
# Since its very CPU demanding, only first 1000 reviews are processe.

# %%
model_lr_bert = LogisticRegression(random_state=12345, solver='liblinear')
model_lr_bert.fit(train_features_bert, train_target[:1000])
# Out:
# LogisticRegression(random_state=12345, solver='liblinear')

# %%
evaluate_model(model_lr_bert, train_features_bert, train_target[:1000], test_features_bert, test_target[:1000])
# Out:
#           train  test
# Accuracy   0.98  0.82
# F1         0.97  0.81
# APS        1.00  0.91
# ROC AUC    1.00  0.90

# %% [markdown]
# Since its very CPU demanding, only first 2000 reviews are processe.

# %%
model_lr_bert = LogisticRegression(random_state=12345, solver='liblinear')
model_lr_bert.fit(train_features_bert2KK, train_target[:2000])
# Out:
# LogisticRegression(random_state=12345, solver='liblinear')

# %%
evaluate_model(model_lr_bert, train_features_bert2K, train_target[:2000], test_features_bert2K, test_target[:2000])
# Out:
#           train  test
# Accuracy   0.96  0.82
# F1         0.96  0.81
# APS        0.99  0.91
# ROC AUC    0.99  0.91

# %% [markdown]
# #### Conclusion

# %% [markdown]
# After checking the 2 implementations of word preprocessing on a Logistic Regression model, the NLTK was performing slightly better, and its pre-processing was much faster.
# The BERT did worst, but it processed only 1000 reviews, while the other used more than 23000 reviews.
# Tried running the BERT on 2000 reviews, but there was no significant difference. I believe that it will perform better, but for that, I'll need a better computer.

# %% [markdown]
# ### LGBMClassifier

# %%
from lightgbm import LGBMClassifier

# %% [markdown]
# #### NLTK, TF-IDF

# %%
# %%time
model_lgbm_nltk=LGBMClassifier(random_state=12345, learning_rate=0.1, max_depth=8, n_estimators=500)
model_lgbm_nltk.fit(tf_idf_nltk_train, train_target)
# Out:
# Wall time: 1min 23s
# LGBMClassifier(max_depth=8, n_estimators=500, random_state=12345)

# %%
evaluate_model(model_lgbm_nltk, tf_idf_nltk_train, train_target, tf_idf_nltk_test, test_target)
# Out:
#           train  test
# Accuracy   0.98  0.87
# F1         0.98  0.87
# APS        1.00  0.94
# ROC AUC    1.00  0.94

# %% [markdown]
# #### spaCy, TF-IDF

# %%
# %%time
model_lgbm_spacy=LGBMClassifier(random_state=12345, learning_rate=0.1, max_depth=8, n_estimators=500)
model_lgbm_spacy.fit(tf_idf_spacy_train, train_target)
# Out:
# Wall time: 1min 17s
# LGBMClassifier(max_depth=8, n_estimators=500, random_state=12345)

# %%
evaluate_model(model_lgbm_spacy, tf_idf_spacy_train, train_target, tf_idf_spacy_test, test_target)
# Out:
#           train  test
# Accuracy   0.98  0.86
# F1         0.98  0.86
# APS        1.00  0.94
# ROC AUC    1.00  0.94

# %% [markdown]
# #### Conclusion

# %% [markdown]
# Like in the Logistic Regression model test, in the test of LGBMClassifier model, the NLTK  performed slightly better, and the Logistic Regression + NLTK performed better than the LGBMClassifier + NLTK.

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### NLTK, TF-IDF

# %%
# %%time
model_rndm_frst_nltk=RandomForestClassifier(random_state=12345, n_estimators=80, max_depth=6)
model_rndm_frst_nltk.fit(tf_idf_nltk_train, train_target)
# Out:
# Wall time: 1.66 s
# RandomForestClassifier(max_depth=6, n_estimators=80, random_state=12345)

# %%
evaluate_model(model_rndm_frst_nltk, tf_idf_nltk_train, train_target, tf_idf_nltk_test, test_target)
# Out:
#           train  test
# Accuracy   0.84  0.81
# F1         0.84  0.82
# APS        0.91  0.88
# ROC AUC    0.92  0.89

# %% [markdown]
# #### spaCy, TF-IDF

# %%
# %%time
model_rndm_frst_spacy=RandomForestClassifier(random_state=12345, n_estimators=80, max_depth=6)
model_rndm_frst_spacy.fit(tf_idf_spacy_train, train_target)
# Out:
# Wall time: 1.81 s
# RandomForestClassifier(max_depth=6, n_estimators=80, random_state=12345)

# %%
evaluate_model(model_rndm_frst_spacy, tf_idf_spacy_train, train_target, tf_idf_spacy_test, test_target)
# Out:
#           train  test
# Accuracy   0.83  0.80
# F1         0.83  0.80
# APS        0.90  0.87
# ROC AUC    0.91  0.88

# %% [markdown]
# #### Conclusion

# %% [markdown]
# The RandomForestClassifier performed purely, and although it had better results for the NLTK, it got results below the desired threshold.

# %%
# Out:
# Using the cpu device.
# ...
# Wall time: 7min 55s

# %% [markdown]
# ## My Reviews

# %% [markdown]
# The task is classifying my text by pre-processing it using the NLTK and spaCy libraries, and the trained model from the previous task.

# %%
# feel free to completely remove these reviews and try your models on your own reviews, 
# those below are just examples

my_reviews = pd.DataFrame([
    'I did not simply like it, not my kind of movie.',
    'Well, I was bored and felt asleep in the middle of the movie.',
    'I was really fascinated with the movie',    
    'Even the actors looked really old and disinterested, and they got paid to be in the movie. What a soulless cash grab.',
    'I didn\'t expect the reboot to be so good! Writers really cared about the source material',
    'The movie had its upsides and downsides, but I feel like overall it\'s a decent flick. I could see myself going to see it again.',
    'What a rotten attempt at a comedy. Not a single joke lands, everyone acts annoying and loud, even kids won\'t like this!',
    'Launching on Netflix was a brave move & I really appreciate being able to binge on episode after episode, of this exciting intelligent new drama.'
], columns=['review'])

my_reviews['review_norm'] = my_reviews.review.apply(clear_text)
my_reviews
# Out:
#                                               review  \
# 0    I did not simply like it, not my kind of movie.
# 1  Well, I was bored and felt asleep in the middl...
# 2             I was really fascinated with the movie
# 3  Even the actors looked really old and disinter...
# 4  I didn't expect the reboot to be so good! Writ...
# 5  The movie had its upsides and downsides, but I...
# 6  What a rotten attempt at a comedy. Not a singl...
# 7  Launching on Netflix was a brave move & I real...
#
#                                          review_norm
# 0      i did not simply like it not my kind of movie
# 1  well i was bored and felt asleep in the middle...
# 2             i was really fascinated with the movie
# 3  even the actors looked really old and disinter...
# 4  i didn't expect the reboot to be so good write...
# 5  the movie had its upsides and downsides but i ...
# 6  what a rotten attempt at a comedy not a single...
# 7  launching on netflix was a brave move i really...

# %% [markdown]
# ### Logistic Regression - NLTK

# %%
texts = my_reviews['review_norm']
my_reviews['lemmas_nltk']=my_reviews.review_norm.apply(lemmatize_nltk)

my_reviews_pred_prob = model_lr_nltk.predict_proba(
    count_tf_idf.transform(
        my_reviews['lemmas_nltk']
    )
)[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.16:  i did not simply like it not my kind of movie
# 0.14:  well i was bored and felt asleep in the middle of the movie
# 0.46:  i was really fascinated with the movie
# 0.12:  even the actors looked really old and disinterested and they got paid to be in the movie what a soul
# 0.30:  i didn't expect the reboot to be so good writers really cared about the source material
# 0.53:  the movie had its upsides and downsides but i feel like overall it's a decent flick i could see myse
# 0.04:  what a rotten attempt at a comedy not a single joke lands everyone acts annoying and loud even kids
# 0.87:  launching on netflix was a brave move i really appreciate being able to binge on episode after episo

# %% [markdown]
# ### Logistic Regression - spaCy

# %%
texts = my_reviews['review_norm']
my_reviews['lemmas_spacy']=my_reviews.review_norm.apply(lemmatize_spacy)

my_reviews_pred_prob = model_lr_spacy.predict_proba(
    count_tf_idf_spacy.transform(
        my_reviews['lemmas_spacy']
    )
)[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.20:  i did not simply like it not my kind of movie
# 0.12:  well i was bored and felt asleep in the middle of the movie
# 0.49:  i was really fascinated with the movie
# 0.10:  even the actors looked really old and disinterested and they got paid to be in the movie what a soul
# 0.27:  i didn't expect the reboot to be so good writers really cared about the source material
# 0.50:  the movie had its upsides and downsides but i feel like overall it's a decent flick i could see myse
# 0.03:  what a rotten attempt at a comedy not a single joke lands everyone acts annoying and loud even kids
# 0.92:  launching on netflix was a brave move i really appreciate being able to binge on episode after episo

# %% [markdown]
# ### BERT

# %%
texts = my_reviews['review_norm']

my_reviews_features_9 = BERT_text_to_embeddings(texts, disable_progress_bar=True)

my_reviews_pred_prob = model_lr_bert.predict_proba(my_reviews_features_9)[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.57:  i did not simply like it not my kind of movie
# 0.01:  well i was bored and felt asleep in the middle of the movie
# 0.93:  i was really fascinated with the movie
# 0.00:  even the actors looked really old and disinterested and they got paid to be in the movie what a soul
# 0.55:  i didn't expect the reboot to be so good writers really cared about the source material
# 0.93:  the movie had its upsides and downsides but i feel like overall it's a decent flick i could see myse
# 0.01:  what a rotten attempt at a comedy not a single joke lands everyone acts annoying and loud even kids
# 1.00:  launching on netflix was a brave move i really appreciate being able to binge on episode after episo

# %% [markdown]
# #### Conclusion - My Reviews

# %% [markdown]
# The probabilities of NLTK and spaCy are very similar.
# The predictor takes the probabilities, if it's equal to or above 0.5 it is 1, else it's 0.
#
# The BERT shows different results, but it is based on a fraction of the reviews dataset, and this is the reason that it performed so differently.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Both NLTK and spaCy showed good language processing capabilities, although NLTK did slightly better. The BERT is known to be better, but lacking the needed resources, I couldn't bring it to its full potential.
# Both NLTK and spaCy managed to get a better F1 score than the minimum required threshold of 0.85.

# %% [markdown]
# # Checklist

# %% [markdown]
# - [x]  Notebook was opened
# - [ ]  The text data is loaded and pre-processed for vectorization
# - [ ]  The text data is transformed to vectors
# - [ ]  Models are trained and tested
# - [ ]  The metric's threshold is reached
# - [ ]  All the code cells are arranged in the order of their execution
# - [ ]  All the code cells can be executed without errors
# - [ ]  There are conclusions
